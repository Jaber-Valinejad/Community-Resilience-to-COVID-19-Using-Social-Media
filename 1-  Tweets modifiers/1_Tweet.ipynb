# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tweepy
import datetime 
consumer_key = "gYUJycQnc3XKMNzl2YIakT0ID"
consumer_secret = "14ZhdDuq9VGj5Zja51POFzfWzRHViAQQYAsmsFkzYNq0dSPc6m"
access_token = "1205328182003609602-LzxarwBW0gikQeeQHJNwkvQg5Taem5"
access_token_secret = "ljOHAPuZmzHyGtU47PQvl3ODwiX6ENBaSjpAgeAnHmC75"


# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)

# %% [markdown]
# Sped up google colab
#
# https://medium.com/@oribarel/getting-the-most-out-of-your-google-colab-2b0585f82403

# %%
import tensorflow as tf
tf.test.gpu_device_name()

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()

# %%
# !kill -9 -1

# %% [markdown]
# #Tweeter historical database
#
# https://catalog.docnow.io/
#
# https://tweetsets.library.gwu.edu/
#
# https://snap.stanford.edu/data/

# %% [markdown]
# # Hydrate
#
# https://github.com/lopezbec/COVID19_Tweets_Dataset/blob/master/Old_Tweets_ID_by_keyword/Automatically_Hydrate_TweetsIDs_COVID19.ipynb

# %% [markdown]
# # Refrences:
# https://programminghistorian.org/en/lessons/beginners-guide-to-twitter-data
#
# https://towardsdatascience.com/twitter-json-data-processing-3f353a5deac4
#
# Example: https://github.com/hectoramirez/Language-localization_FIFA
#
# Tweeter REST API: https://towardsdatascience.com/downloading-data-from-twitter-using-the-rest-api-24becf413875

# %% [markdown]
# # Fact cheking
# https://www.truthorfiction.com/search/?q=covid%2019&_siq_page=1&_siq_sort=relevance
#
# https://leadstories.com/
#
# https://www.politifact.com/
#
# https://www.poynter.org/covid-19-poynter-resources/
#
# https://www.factcheck.org/a-guide-to-our-coronavirus-coverage/
#
# https://www.snopes.com/
#
# https://euvsdisinfo.eu/
#
# Newsguard is a browser extension that manually labels websites on a score from 0-100 on reputability, though.

# %% [markdown]
# # Covid 19
#
# https://ieee-dataport.org/open-access/coronavirus-covid-19-tweets-dataset

# %% [markdown]
# # Mapping
# https://www.tableau.com/
#
# https://programminghistorian.org/en/lessons/mapping-with-python-leaflet
#
# https://digitalfellows.commons.gc.cuny.edu/2019/06/03/finding-the-right-tools-for-mapping/

# %% [markdown]
# # Web scrapper
#
# https://www.webscraper.io/tutorials

# %% [markdown]
# # Creat a world map
#
# https://towardsdatascience.com/using-python-to-create-a-world-map-from-a-list-of-country-names-cd7480d03b10

# %%
import os, sys
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
# Australia
#dt_adult = pd.read_csv('/content/drive/Shareddrives/MY Files/W IEEEmsc:resilience+fake news+Web scrapping/1-  Tweets modifiers/Country Tweetsss/Australia_tweet-ids.csv')
#Brazil
#dt_adult = pd.read_csv('/content/drive/Shareddrives/MY Files/W IEEEmsc:resilience+fake news+Web scrapping/1-  Tweets modifiers/Country Tweetsss/Brazil_tweet-ids.csv')
#China
#dt_adult = pd.read_csv('/content/drive/Shareddrives/MY Files/W IEEEmsc:resilience+fake news+Web scrapping/1-  Tweets modifiers/Country Tweetsss/China_tweet-ids.csv')
#Iran
#dt_adult = pd.read_csv('/content/drive/Shareddrives/MY Files/W IEEEmsc:resilience+fake news+Web scrapping/1-  Tweets modifiers/Country Tweetsss/Iran_tweet-ids.csv')
#Italy
#dt_adult = pd.read_csv('/content/drive/Shareddrives/MY Files/W IEEEmsc:resilience+fake news+Web scrapping/1-  Tweets modifiers/Country Tweetsss/Italy_tweet-ids.csv')
#Singapour
#dt_adult = pd.read_csv('/content/drive/Shareddrives/MY Files/W IEEEmsc:resilience+fake news+Web scrapping/1-  Tweets modifiers/Country Tweetsss/Singapore_tweet-ids.csv')
#South Korea
#dt_adult = pd.read_csv('/content/drive/Shareddrives/MY Files/W IEEEmsc:resilience+fake news+Web scrapping/1-  Tweets modifiers/Country Tweetsss/SouthKorea_tweet-ids.csv')
#UK
#dt_adult = pd.read_csv('/content/drive/Shareddrives/MY Files/W IEEEmsc:resilience+fake news+Web scrapping/1-  Tweets modifiers/Country Tweetsss/UK_tweet-ids.csv')
#USA
dt_adult = pd.read_csv('/content/drive/Shareddrives/MY Files/W IEEEmsc:resilience+fake news+Web scrapping/1-  Tweets modifiers/Country Tweetsss/US_tweet-ids.csv')

#pd.read_csv
dt_adult=dt_adult.sample(n=60000)#or(frac = 0.5)
print('Size of data before sampling:',dt_adult.shape)
Data=pd.DataFrame(dt_adult)
Data.head()
#Data.columns
# Out:
# Size of data before sampling: (60000, 34)
# Size of data before sampling: (60000, 34)

# %%
data_tweet = pd.DataFrame()
data_tweet['Time']= Data['created_at']
data_tweet['text']= Data['text']
data_tweet['user_followers_count']= Data['user_followers_count']
data_tweet['user_followee_count']= Data['user_friends_count']
data_tweet['lang']= Data['lang']
data_tweet.head()
# Out:
#                                   Time  ... lang
# 68399   Mon Jun 22 10:47:24 +0000 2020  ...   de
# 51518   Fri Jul 31 14:07:18 +0000 2020  ...   en
# 21949   Sat Aug 22 22:46:49 +0000 2020  ...   en
# 44420   Mon Nov 02 07:26:02 +0000 2020  ...   vi
# 109665  Fri Jun 19 09:40:06 +0000 2020  ...  und
#
# [5 rows x 5 columns]

# %% [markdown]
# # Date

# %%
import time
OK=data_tweet['Time']
df = pd.DataFrame()
df['Time']=''

for i in range(OK.shape[0]):
   X=OK[i]
   #Y= time.strftime('%Y%m%d%H', time.strptime(X,'%a %b %d %H:%M:%S +0000 %Y'))
   Y= time.strftime('%Y%m', time.strptime(X,'%a %b %d %H:%M:%S +0000 %Y'))
   df.at[i,'Time']=pd.to_numeric(Y)


#data_tweet['Time']
data_tweet.drop(['Time'], axis=1, inplace=True)
data_tweet['time']=df['Time']
data_tweet=data_tweet.sort_values(by=['time'])
data_tweet2=data_tweet.copy()
data_tweet.head(10)
# Out:
#                                                     text  ...    time
# 15642  Woolworths to hold daily elderly and disabilit...  ...  202003
# 44817  Harmer updates on Covid-19 as IAG completes In...  ...  202003
# 44814  RT @RealRickGlaser1: I've talked to #boxing gu...  ...  202003
# 13134  #Australia PM says social distancing helping t...  ...  202003
# 13135  RT @PressTV: #Coronavirus hysteria: Customers ...  ...  202003
# 44812  RT @hamrahshowaziz: #Coronavirus in #Iran,Cove...  ...  202003
# 13137  RT @ReutersLatam: #Australia 🇦🇺 cierra la popu...  ...  202003
# 44808  RT @savillj013: #Australia #covid19 at day 14 ...  ...  202003
# 44804  RT @V2019N: #Australia virologist @MackayIM lo...  ...  202003
# 44803  RT @ReutersLatam: Investigadores de #Australia...  ...  202003
#
# [10 rows x 5 columns]

# %%
data_tweet.index=range(data_tweet.shape[0])

# %%
data_tweet.shape[0]
# Out:
# 32713

# %%
n=0
for i in range(data_tweet.shape[0]):
   if data_tweet['lang'][i] != 'en':
       #data = data.drop(labels=[i], axis=0)
       n=n+1
print(n)
# Out:
# 23507

# %%
data_tweet['time'].max()
data_tweet['Time hour'].max()
# Out:
# 2017091109.0

# %% [markdown]
# Mixing days: text

# %%
#daily
#data_tweet.drop(['id','user_followers_count','user_followee_count','lang','user_location',"Month","Day",'Hour','Year','Time hour'], axis=1, inplace=True)
##data_tweet1 = data_tweet.groupby(["Month","Day",'Hour']).sum()
#data_tweet1 = data_tweet.groupby(['time']).sum()
#data_tweet1.head()
##data_tweet1['text'][20170825]


#hourly
data_tweet.drop(['id','user_followers_count','user_followee_count','lang','user_location',"Month","Day",'Hour','Year','time'], axis=1, inplace=True)
data_tweet1 = data_tweet.groupby(['Time hour']).sum()
data_tweet1.head()
# Out:
#                                                            text
# Time hour
# 2.017083e+09  RT @PHEgov: Do you rely on electricity powered...
# 2.017083e+09  What happening twitter? Oh just hunkering down...
# 2.017083e+09  Good advice for those in need of electricity p...
# 2.017083e+09  Electricity just went out while at target, Hur...
# 2.017083e+09  RT @Adam_Sieminski: Track #HurricaneHarvey on ...

# %% [markdown]
# Mixing days: frequency

# %%
#hourly

data_tweet2.drop(['id','user_followers_count','text','user_followee_count','lang','user_location',"Month","Day",'Hour','Year','time'], axis=1, inplace=True)
#data_tweet.drop(['id','user_followers_count','language','location','location_code' ], axis=1, inplace=True)
#Data_tweet['time']-=20170000 
data_tweet_frequency = data_tweet2.pivot_table(index=['Time hour'], aggfunc='size')
data_tweet=data_tweet2.groupby(['Time hour']).sum()
data_tweet['frequency']=data_tweet_frequency 
data_tweet.head()
ALL_Data=data_tweet.merge(data_tweet1, on='Time hour')
ALL_Data.head()
#data_tweet.to_excel('/content/drive/Shareddrives/MY Files/Tweeter Data/output.xlsx')
# Out:
#               frequency                                               text
# Time hour
# 2.017083e+09          8  RT @PHEgov: Do you rely on electricity powered...
# 2.017083e+09          4  What happening twitter? Oh just hunkering down...
# 2.017083e+09          6  Good advice for those in need of electricity p...
# 2.017083e+09          6  Electricity just went out while at target, Hur...
# 2.017083e+09          1  RT @Adam_Sieminski: Track #HurricaneHarvey on ...

# %% [markdown]
# # Languages

# %% [markdown]
# **json**

# %%
! sudo pip3 install simplejson
import simplejson as json
# Out:
# Requirement already satisfied: simplejson in /usr/local/lib/python3.7/dist-packages (3.17.2)

# %%
with open('/content/drive/Shareddrives/MY Files/Tweeter Data/languages.json', 'r', encoding='utf-8') as json_file:
    languages_dict = json.load(json_file)
    
names = []
for idx, row in data_tweet.iterrows():
    lang = row['lang']
    if lang == 'und':
        names.append(None)
    elif lang == 'in':
        name = languages_dict['id']['name']
        names.append(name)
    elif lang == 'iw':
        name = languages_dict['he']['name']
        names.append(name)
    else:
        name = languages_dict[lang]['name']
        names.append(name)

data_tweet['language'] = names
data_tweet.drop(['lang'], axis=1, inplace=True)
data_tweet.head()
# Out:
#                                                     text  ...  language
# 31885  RT @jsblokland: #SouthKorea today added less t...  ...   English
# 41017  RT @Taheri_Movement: The head of the @WHO , @D...  ...   English
# 13372  தென்கொரியாவில் கொரோனா வைரஸ் பாதிக்கப்பட்டோர் எ...  ...     Tamil
# 13369  RT @GordonGChang: On @i24NEWS_EN at 5:20 ET to...  ...   English
# 35127  RT @FXstreetNews: South Korea confirms 518 new...  ...   English
#
# [5 rows x 5 columns]

# %% [markdown]
# # Translation

# %% [markdown]
# https://stackoverflow.com/questions/52455774/googletrans-stopped-working-with-error-nonetype-object-has-no-attribute-group/52456197#52456197

# %%
#pip install googletrans==3.1.0a0
# !pip install google_trans_new
# Out:
# Requirement already satisfied: google_trans_new in /usr/local/lib/python3.7/dist-packages (1.1.9)

# %%
data_tweet.index=list(range(data_tweet.shape[0]))
data_tweet['translated']=''

from google_trans_new import google_translator  
translator = google_translator()
for i in range(data_tweet.shape[0]):
    if   data_tweet['text'][i] !=np.nan   and  data_tweet['language'][i] != 'English':
        TEXT=data_tweet['text'][i]
        translate_text = translator.translate(TEXT,lang_tgt='en')
        data_tweet.at[i,'translated']=translate_text
    else:
        data_tweet.at[i,'translated']=data_tweet['text'][i]
data_tweet.head(20)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/google_trans_new/google_trans_new.py in translate(self, text, lang_tgt, lang_src, pronounce)
#     188                         raise e
# --> 189             r.raise_for_status()
#     190         except requests.exceptions.ConnectTimeout as e:
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://translate.google.cn/_/TranslateWebserverUi/data/batchexecute&q=EgQiVtF-GMThhIMGIhkA8aeDS4Bq8zNTrMGKLv8gavwe2USQaoApMgFy
#
# During handling of the above exception, another exception occurred:
#
# google_new_transError                     Traceback (most recent call last)
# <ipython-input-48-5c372b397bdc> in <module>()
#       7     if   data_tweet['text'][i] !=np.nan   and  data_tweet['language'][i] != 'English':
#       8         TEXT=data_tweet['text'][i]
# ----> 9         translate_text = translator.translate(TEXT,lang_tgt='en')
#      10         data_tweet.at[i,'translated']=translate_text
#      11     else:
#
# /usr/local/lib/python3.7/dist-packages/google_trans_new/google_trans_new.py in translate(self, text, lang_tgt, lang_src, pronounce)
#     192         except requests.exceptions.HTTPError as e:
#     193             # Request successful, bad response
# --> 194             raise google_new_transError(tts=self, response=r)
#     195         except requests.exceptions.RequestException as e:
#     196             # Request failed
#
# google_new_transError: 429 (Too Many Requests) from TTS API. Probable cause: Unknown

# %%
data_tweet.to_excel("SouthKorea.xlsx",sheet_name='Sheet_name_1')

# %% [markdown]
# # Text cleaning

# %%
import nltk
nltk.download('stopwords')
import re
import pandas as pd
import nltk
import string
from nltk.corpus import stopwords
#from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import regexp
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
#import docx
#import docx2txt
ALL_Data=data_tweet 
ALL_Data['texte_cleaned']=''
#result = docx2txt.process("C:/Users/JabV/Desktop/DAta Cleaned/RD  monthly/Real/SF/7 July.docx")




def remove_html(text):
    """Remove special patterns - email, url, date etc."""
    email_regex = re.compile(r"[\w.-]+@[\w.-]+")
    url_regex = re.compile(r"(http|www)[^\s]+")
    date_regex = re.compile(r"[\d]{2,4}[ -/:]*[\d]{2,4}([ -/:]*[\d]{2,4})?") # a way to match date
    ## remove
    text = url_regex.sub("", text)
    text = email_regex.sub("", text)
    text = date_regex.sub("", text)
    return text



def remove_punctuation(text):
    no_punct="".join([c for c in text if c not in string.punctuation])
    return no_punct



#1 No tokenize
#tokenized_text=result2.lower()

#2 Tokenize
word_tokenizer = regexp.WhitespaceTokenizer()
#tokenized_text = [word.lower() for word in word_tokenizer.tokenize(result2)]


def remove_stopwords(text):
    words=[w for w in text if w not in stopwords.words('english')]
    return words

  
stemmer=PorterStemmer()
def word_stemmer(text):
    stem_text=" ".join([stemmer.stem(i) for i in text])
    return stem_text



for i in range(ALL_Data.shape[0]):
  j=ALL_Data.index[i]
  result=ALL_Data['text'][j]
  result1=remove_html(result)
  result2=remove_punctuation(result1)
  tokenized_text = [word.lower() for word in word_tokenizer.tokenize(result2)]
  result3=remove_stopwords(tokenized_text)
  result4=word_stemmer(result3)
  ALL_Data.at[j,'texte_cleaned']=result4
ALL_Data.head()
#mydoc = docx.Document()
#mydoc.add_paragraph(result4)
#mydoc.save("C:/Users/JabV/Desktop/DAta Cleaned/RD  monthly/Real/SF/7 July.docx")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                 text  ...                                      texte_cleaned
# 0  Woolworths to hold daily elderly and disabilit...  ...  woolworth hold daili elderli disabilityonli sh...
# 1  Harmer updates on Covid-19 as IAG completes In...  ...  harmer updat covid19 iag complet india sale in...
# 2  RT @RealRickGlaser1: I've talked to #boxing gu...  ...  rt realrickglaser1 ive talk box guy australia ...
# 3  #Australia PM says social distancing helping t...  ...  australia pm say social distanc help slow coro...
# 4  RT @PressTV: #Coronavirus hysteria: Customers ...  ...  rt presstv coronaviru hysteria custom australi...
#
# [5 rows x 7 columns]

# %%
ALL_Data.to_excel("ALL_Data.xlsx",
             sheet_name='Sheet_name_1')

# %% [markdown]
# Additional

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

def cleaner(string):
    
    # Generate list of tokens
    doc = nlp(string)
    lemmas = [token.lemma_ for token in doc]    # Remove tokens that are not alphabetic 
    a_lemmas = [lemma for lemma in lemmas if lemma.isalpha() 
                 or lemma == '-PRON-']     # Print string after text cleaning
    return ' '.join(a_lemmas)

#data_tweet['text_cleaned'] = \
#                   data_tweet['text'].progress_apply(cleaner)

#data_tweet['text_cleaned'] = \
#                   data_tweet['text'].progress_apply(cleaner)

# %% [markdown]
# # user-locations

# %%
# !pip install country-converter
import country_converter as coco

# change codes to iso3 
to_iso3_func = lambda x: coco.convert(names=x, to='iso3', not_found=None) \
                            if x is not None else x
to_std_func = lambda x: coco.convert(names=x, to='name_short', not_found=None) \
                            if x is not None else x
# Out:
# Requirement already satisfied: country-converter in /usr/local/lib/python3.7/dist-packages (0.7.2)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from country-converter) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->country-converter) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->country-converter) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->country-converter) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.17.0->country-converter) (1.15.0)

# %%
from geopy.geocoders import Nominatim
from tqdm import tqdm

tqdm.pandas()

def geo_locator(user_location):
    
    # initialize geolocator
    geolocator = Nominatim(user_agent='Tweet_locator')

    if user_location is not None:
        try :
            # get location
            location = geolocator.geocode(user_location, language='en')
            # get coordinates
            location_exact = geolocator.reverse(
                        [location.latitude, location.longitude], language='en')
            # get country codes
            c_code = location_exact.raw['address']['country_code']

            return c_code

        except:
            return None

    else : 
        return None

# apply geo locator to user-location
loc = data_tweet['user_location'].progress_apply(geo_locator)
data_tweet['user-country_code'] = loc

# change codes to iso3 
data_tweet['user-country_code'] = \
                    data_tweet['user-country_code'].apply(to_iso3_func)

# create user-country column
data_tweet['user-country'] = \
                    data_tweet['user-country_code'].apply(to_std_func)
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#  20%|██        | 2/10 [00:00<00:03,  2.65it/s]
#  30%|███       | 3/10 [00:01<00:03,  1.78it/s]
#  40%|████      | 4/10 [00:02<00:04,  1.42it/s]
#  50%|█████     | 5/10 [00:03<00:03,  1.28it/s]
#  60%|██████    | 6/10 [00:04<00:03,  1.17it/s]
#  70%|███████   | 7/10 [00:05<00:02,  1.12it/s]
#  80%|████████  | 8/10 [00:06<00:01,  1.08it/s]
#  90%|█████████ | 9/10 [00:07<00:00,  1.04it/s]
# 100%|██████████| 10/10 [00:09<00:00,  1.03it/s]

# %%
# drop old column
#data_tweet.drop(['user_location','coordinates','user-country_code','place' ], axis=1, inplace=True)
#data_tweet.drop(['user_location','user-country_code','place' ], axis=1, inplace=True)
data_tweet['location'] = data_tweet['user-country'] 
data_tweet['location_code'] = data_tweet['user-country_code'] 
data_tweet.drop(['user_location','user-country','user-country_code' ], axis=1, inplace=True)
data_tweet.head(30)
# Out:
#                     id  ... location_code
# 0  1246581929912094720  ...           AFG
# 1  1243506148923367424  ...           BRA
# 2  1266323498168750083  ...           IND
# 3  1240796235591585793  ...           AFG
# 4  1238660920836067328  ...           IRN
# 5  1256405946198142977  ...           KOR
# 6  1273921404182958082  ...           AFG
# 7  1298930913485545474  ...           CHN
# 8  1293994646826360832  ...           RUS
# 9  1247880631461216256  ...           USA
#
# [10 rows x 9 columns]

# %% [markdown]
# # Sentiment Analysis

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

df_sentiment = df_english.copy()

# instantiate new SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

sentiment_scores = df_sentiment['text_cleaned'].progress_apply(
                                                            sid.polarity_scores)
sentiment = sentiment_scores.apply(lambda x: x['compound'])
df_sentiment['sentiment'] = sentiment
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 3481.04it/s]
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df_sentiment.head()
# Out:
#                    id                            Time  ... text_english  sentiment
# 0  905480659724103687  Wed Sep 06 17:19:46 +0000 2017  ...          NaN     0.3382
# 1  904893643571380224  Tue Sep 05 02:27:11 +0000 2017  ...          NaN     0.5994
# 2  901184978679205897  Fri Aug 25 20:50:16 +0000 2017  ...          NaN     0.5267
# 3  906477448145010688  Sat Sep 09 11:20:39 +0000 2017  ...          NaN    -0.5423
# 4  901834179125673985  Sun Aug 27 15:49:58 +0000 2017  ...          NaN     0.0000
#
# [5 rows x 10 columns]

# %% [markdown]
# # finishing

# %%
#cols_order = ['text', 'language', 'location', 'location_code', 
#              'location-coordinates', 'sentiment', 'text_english', 
#              'text_cleaned', 'user-screen_name']
#df_final = df_sentiment[cols_order]

# %% [markdown]
# # Extra: a simple analysis

# %%
import plotly.express as px

countries_lang = pd.read_excel('/content/drive/Shareddrives/MY Files/Tweeter Data/countries_lang_full.xlsx', index_col=0)

tweets_loc = df_sentiment.copy()

# group tweets by location
agg = {'text': 'count', 'sentiment': 'mean'}
tweets_loc = tweets_loc.groupby('location').agg(agg)
tweets_loc.sort_values(by='sentiment', ascending=False, inplace=True)
tweets_loc = tweets_loc.rename(columns={'text':'count'})

# get country codes
codes = []
for loc in tweets_loc.index:
    code = countries_lang[countries_lang.Country_name==loc]['Country_code']
    codes.append(code.values[0])
tweets_loc['country_code'] = codes

tweets_loc.reset_index(inplace=True)

# Plotly
fig = px.choropleth(tweets_loc, locations="country_code", 
                    color='sentiment',
                    hover_name='location', 
                    hover_data=['count'], 
                    color_continuous_scale='ice', scope='world') 

fig.update_layout(
    title_text = "Mean Twitter sentiment score by country",
    
    geo=dict(showframe=False, showcoastlines=False, 
             projection_type='equirectangular'),
    
    annotations = [dict(x=-0.04, y=0.95, xref='paper', yref='paper',
        text='Sentiment of Hurricane', 
        showarrow=False)]
)

fig.update_geos(resolution=110, showcountries=False, 
                lataxis_range=[-55, 90], lonaxis_range=[-180, 180])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f326c6e9-d2a3-4cf5-b760-89c83c4fdcc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f326c6e9-d2a3-4cf5-b760-89c83c4fdcc0")) {
#                     Plotly.newPlot(
#                         'f326c6e9-d2a3-4cf5-b760-89c83c4fdcc0',
#                         [{"coloraxis": "coloraxis", "customdata": [[1], [1], [1], [1], [48], [2], [12], [1], [4], [13], [1], [1], [1], [1]], "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>count=%{customdata[0]}<br>country_code=%{location}<br>sentiment=%{z}", "hovertext": ["Netherlands", "Romania", "Israel", "Spain", "United States", "France", "Afghanistan", "Norway", "Canada", "United Kingdom", "Japan", "Laos", "Germany", "Sweden"], "locations": ["NLD", "ROU", "ISR", "ESP", "USA", "FRA", "AFG", "NOR", "CAN", "GBR", "JPN", "LAO", "DEU", "SWE"], "name": "", "type": "choropleth", "z": [0.7206, 0.5994, 0.0, 0.0, -0.05093958333333332, -0.14934999999999998, -0.2353583333333333, -0.296, -0.318125, -0.4611461538461539, -0.5267, -0.5719, -0.6369, -0.6369]}],
#                         {"annotations": [{"showarrow": false, "text": "Sentiment of Hurricane", "x": -0.04, "xref": "paper", "y": 0.95, "yref": "paper"}], "coloraxis": {"colorbar": {"title": {"text": "sentiment"}}, "colorscale": [[0.0, "rgb(3, 5, 18)"], [0.09090909090909091, "rgb(25, 25, 51)"], [0.18181818181818182, "rgb(44, 42, 87)"], [0.2727272727272727, "rgb(58, 60, 125)"], [0.36363636363636365, "rgb(62, 83, 160)"], [0.45454545454545453, "rgb(62, 109, 178)"], [0.5454545454545454, "rgb(72, 134, 187)"], [0.6363636363636364, "rgb(89, 159, 196)"], [0.7272727272727273, "rgb(114, 184, 205)"], [0.8181818181818182, "rgb(149, 207, 216)"], [0.9090909090909091, "rgb(192, 229, 232)"], [1.0, "rgb(234, 252, 253)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "lataxis": {"range": [-55, 90]}, "lonaxis": {"range": [-180, 180]}, "projection": {"type": "equirectangular"}, "resolution": 110, "scope": "world", "showcoastlines": false, "showcountries": false, "showframe": false}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoord ...

# %% [markdown]
# # LIWC
#
# **dictionary:**
# http://www.liwc.net/dictionaries/index.php/liwcdic/7

# %%
#!pip install liwc-text-analysis
#from liwc import Liwc
#liwc = Liwc('/content/drive/Shareddrives/MY Files/Tweeter Data/LIWC dictionary/LIWC2015-jfx.jar')

# %% [markdown]
# # **bigram**

# %%
import re
import pandas as pd
import nltk
import string
from nltk.corpus import stopwords
from nltk import bigrams
import collections
from nltk.tokenize import regexp
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
import docx
import docx2txt
import seaborn as sns
import itertools
import matplotlib.pyplot as plt
import networkx as nx
sns.set(font_scale=1.5)
sns.set_style("whitegrid")

result = docx2txt.process("C:/Users/JabV/Desktop/Web sceinec2020/Work 5 Data analysis/DAta Cleaned/News Monthly/All.docx")



def remove_html(text):
    """Remove special patterns - email, url, date etc."""
    email_regex = re.compile(r"[\w.-]+@[\w.-]+")
    url_regex = re.compile(r"(http|www)[^\s]+")
    date_regex = re.compile(r"[\d]{2,4}[ -/:]*[\d]{2,4}([ -/:]*[\d]{2,4})?") # a way to match date
    ## remove
    text = url_regex.sub("", text)
    text = email_regex.sub("", text)
    text = date_regex.sub("", text)
    return text


result1=remove_html(result)


def remove_punctuation(text):
    no_punct="".join([c for c in text if c not in string.punctuation])
    return no_punct


result2=remove_punctuation(result1)

#1 No tokenize
#tokenized_text=result2.lower()

#2 Tokenize
word_tokenizer = regexp.WhitespaceTokenizer()
tokenized_text = [word.lower() for word in word_tokenizer.tokenize(result2)]



def remove_stopwords(text):
    words=[w for w in text if w not in stopwords.words('english')]
    return words

result3=remove_stopwords(tokenized_text)



result5=[result3]

terms_bigram = [list(bigrams(x)) for x in result5]
bigrams = list(itertools.chain(*terms_bigram))
bigram_counts = collections.Counter(bigrams)

#print(bigram_counts.most_common(5))



# 5- table by panda
bigram_df = pd.DataFrame(bigram_counts.most_common(20),
                             columns=['bigram', 'count'])

print(bigram_df)
#6-  Visualize Networks of Bigrams

# Create dictionary of bigrams and their counts
d = bigram_df.set_index('bigram').T.to_dict('records')


# Create network plot 
G = nx.Graph()

# Create connections between nodes
for k, v in d[0].items():
    G.add_edge(k[0], k[1], weight=(v * 10))

G.add_node("China", weight=100)





fig, ax = plt.subplots(figsize=(6, 4))

pos = nx.spring_layout(G, k=2)

# Plot networks
nx.draw_networkx(G, pos,
                 font_size=100,
                 width=5,
                 edge_color='grey',
                 node_color='purple',
                 with_labels = False,
                 ax=ax)

# Create offset labels
for key, value in pos.items():
    x, y = value[0]+.135, value[1]+.045
    ax.text(x, y,
            s=key,
            bbox=dict(facecolor='red', alpha=0.25),
            horizontalalignment='center', fontsize=13)
    
plt.show()

# %% [markdown]
# # **NEWS API**  (only past 20 days)

# %%
# !pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Downloading newsapi_python-0.2.6-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.7/dist-packages (from newsapi-python) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->newsapi-python) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->newsapi-python) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->newsapi-python) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->newsapi-python) (3.0.4)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.6

# %%
import pandas as pd
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='3446f68fc41745c0b6ad72e0bf2d7134')

# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='covid',
                                         #sources='bbc-news,the-verge',
                                          category='business',
                                          language='en',
                                          country='us')


# /v2/everything
all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2021-08-01',
                                      to='2021-08-04',
                                      language='en',
                                      sort_by='relevancy'
                                     )


# /v2/sources
sources = newsapi.get_sources()


## Let's make a request to get live top headlines in the US
## right now. We'll use the /top-headlines endpoint for this.
import requests
url = ('http://newsapi.org/v2/top-headlines?'
       'country=us&'
       'apiKey=3446f68fc41745c0b6ad72e0bf2d7134')
response = requests.get(url)
print(response.json())


## If you want headlines just from a specific source,
##for example BBC News, we can do that too.

# News resources: https://newsapi.org/sources 

import requests
url = ('http://newsapi.org/v2/top-headlines?'
       'sources=bbc-news&'
       'apiKey=3446f68fc41745c0b6ad72e0bf2d7134')
response = requests.get(url)
print(response.json())



## I want to search for news articles that mention a
## specific topic or keyword

import requests

url = ('http://newsapi.org/v2/everything?'
       'q=Apple&'
       'from=2020-05-19&'
       'sortBy=popularity&'
       'apiKey=3446f68fc41745c0b6ad72e0bf2d7134')

response =requests.get(url)

print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 38, 'articles': [{'source': {'id': None, 'name': 'CBS Sports'}, 'author': '', 'title': 'NBA free agency winners and losers: Lakers defense takes hit; Heat make power moves; Bulls go all-in - CBS Sports', 'description': "Here's a look at the best and worst from 2021 NBA free agency so far", 'url': 'https://www.cbssports.com/nba/news/nba-free-agency-winners-and-losers-lakers-defense-takes-hit-heat-make-power-moves-bulls-go-all-in/', 'urlToImage': 'https://sportshub.cbsistatic.com/i/r/2021/06/05/087d5f4f-b71d-4217-a4ae-d384a1135d27/thumbnail/1200x675/647c550569af1bc6abe9f9302a327b88/lebron-2.jpg', 'publishedAt': '2021-08-04T14:17:00Z', 'content': 'NBA free agency officially began on Monday, with teams and players wasting no time coming to terms on lucrative deals throughout the league. The defending Western Conference champion Phoenix Suns got… [+13033 chars]'}, {'source': {'id': None, 'name': 'New York Times'}, 'author': 'Ben Hubbard, Bryan Denton', 'title': 'Collapse: Inside Lebanon’s Worst Economic Meltdown in More Than a Century - The New York Times', 'description': 'The small Mediterranean country is in the throes of a financial crisis that the World Bank has said could rank among the world’s worst since the mid-1800s.', 'url': 'https://www.nytimes.com/2021/08/04/world/lebanon-crisis.html', 'urlToImage': 'https://static01.nyt.com/images/2021/07/25/world/00lebanon-collapse1/00lebanon-collapse1-facebookJumbo-v2.jpg', 'publishedAt': '2021-08-04T14:06:41Z', 'content': 'Lebanon, a small Mediterranean country still haunted by a 15-year civil war that ended in 1990, is in the throes of a financial collapse that the World Bank has said could rank among the worlds worst… [+1356 chars]'}, {'source': {'id': None, 'name': 'CNBC'}, 'author': 'Dan Mangan', 'title': 'Trump lawyers ask judge to block release of tax returns to Congress after Biden DOJ orders IRS to do so - CNBC', 'description': 'Trump has fought the release of his income tax returns for years. The Biden Justice Department says the IRS has to give Congress those documents.', 'url': 'https://www.cnbc.com/2021/08/04/trump-asks-judge-to-block-tax-returns-release-to-congress-after-doj-order.html', 'urlToImage': 'https://image.cnbcfm.com/api/v1/image/106907719-1625676442770-gettyimages-1327493808-2p2a4676_20210707120359997.jpeg?v=1628083242', 'publishedAt': '2021-08-04T14:02:02Z', 'content': "Attorneys for former President Donald Trump asked a federal judge Wednesday to block a Justice Department order that the IRS turn over years of his income tax returns to Congress.\r\nTrump's lawyers ar… [+2587 chars]"}, {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'}, 'author': 'TIMESOFINDIA.COM', 'title': "Delta surge: How an overseas flight from Moscow broke through China's Covid defences - Times of India", 'description': "China News: NEW DELHI: The fast-spreading Delta variant seems to have broken through China's Covid defences as the country battles its worst outbreak since the vi.", 'url': 'https://timesofindia.indiatimes.com/world/china/delta-surge-how-an-overseas-flight-from-moscow-broke-through-chinas-covid-defences/articleshow/85039085.cms', 'urlToImage': 'https://static.toiimg.com/thumb/msid-85039499,width-1070,height-580,imgsize-810445,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg', 'publishedAt': '2021-08-04T13:55:00Z', 'content': "Delta surge: How an overseas flight from Moscow broke through China's Covid defences"}, {'source': {'id': None, 'name': 'New York Post'}, 'author': 'Emily Crane', 'title': 'Texas Gov. Greg Abbott hits back after judge blocks illegal immigration order - New York Post ', 'description': 'A federal judge blocked Texas Governor Greg Abbott’s executive order allowing troopers to stop vehicles suspected of carrying illegal immigrants over fears they could spread COVID-19.', 'url': 'https://nypost.com/2021/08/04/texas-governor-responds-as-judge-blocks-illegal-immigration-order/', 'urlToImage': 'http ...
# {'status': 'ok', 'totalResults': 10, 'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'Belarus protests: Trial of opposition figures begins', 'description': 'Protest organiser Maria Kolesnikova has been charged with threatening national security.', 'url': 'http://www.bbc.co.uk/news/world-europe-58083672', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/14179/production/_119779228_gettyimages-1234447249.jpg', 'publishedAt': '2021-08-04T15:37:28.2582921Z', 'content': 'image captionMaria Kolesnikova and Maxim Znak appeared at a court in the capital Minsk on Wednesday\r\nThe trial of two leading Belarusian opposition figures has begun behind closed doors at a court in… [+4202 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "BA flight 149: Was it on a secret 'military intelligence mission'?", 'description': 'Passengers and crew were taken hostage by Iraq when the flight landed in Kuwait in 1990.', 'url': 'http://www.bbc.co.uk/news/uk-58087520', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/E4A0/production/_119782585_baflight149.jpg', 'publishedAt': '2021-08-04T15:37:20.5414627Z', 'content': 'By Gordon CoreraSecurity correspondent\r\nimage sourceColin Davey/Getty Images\r\nimage captionAfter the crew and passengers had disembarked, the aircraft was destroyed on the runway\r\nFor years there has… [+5149 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC Sport', 'title': "Canada's De Grasse wins 200m gold", 'description': "Canada's Andre de Grasse finishes fast to overhaul world champion Noah Lyles and win the Olympic 200m title.", 'url': 'http://www.bbc.co.uk/sport/olympics/58088922', 'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/142D8/production/_119784628_degrasse_getty.jpg', 'publishedAt': '2021-08-04T15:22:24.4087098Z', 'content': '<table><tr><th>Tokyo Olympic Games on the BBC</th></tr>\r\n<tr><td>Dates: 23 July-8 August Time in Tokyo: BST +8</td></tr><tr><td>Coverage: Watch live on BBC TV, BBC iPlayer, BBC Red Button and online;… [+4384 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "Delhi rape and murder: Indians protest over Dalit girl's forced cremation", 'description': 'A couple accuse a priest and three others of raping and murdering their daughter, aged nine.', 'url': 'http://www.bbc.co.uk/news/world-asia-india-58083052', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/164A1/production/_119779219_screenshot2021-08-04at00.23.38.png', 'publishedAt': '2021-08-04T14:22:20.2182112Z', 'content': 'By Salman RaviBBC Hindi, Delhi\r\nimage captionProtesters outside the crematorium are demanding the death penalty for the accused\r\nProtests are continuing for the fourth day over the alleged gang rape,… [+3966 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC Sport', 'title': 'Are super shoes & springy track helping break records at Tokyo 2020?', 'description': 'World records have tumbled on the athletics track at Tokyo 2020, but how much of that is down to new "super shoes" and a springy Olympics track built for speed?', 'url': 'http://www.bbc.co.uk/sport/olympics/58084865', 'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/14D8B/production/_119778358_00000index.png', 'publishedAt': '2021-08-04T13:22:27.8165896Z', 'content': '<table><tr><th>Tokyo Olympic Games on the BBC</th></tr>\r\n<tr><td>Dates: 23 July-8 August Time in Tokyo: BST +8</td></tr><tr><td>Coverage: Watch live on BBC TV, BBC iPlayer, BBC Red Button and online;… [+4336 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'The Offspring drummer Pete Parada says he was dropped over vaccine refusal', 'description': 'Pete Parada says a doctor advised him not to have the jab because of a rare autoimmune disorder.', 'url': 'http://www.bbc.co.uk/news/entertain ...
# {'status': 'error', 'code': 'parameterInvalid', 'message': 'You are trying to request results too far in the past. Your plan permits you to request articles as far back as 2021-07-03, but you have requested 2020-05-19. You may need to upgrade to a paid plan.'}

# %%
all_articles
# Out:
# {'articles': [{'author': 'https://www.facebook.com/bbcnews',
#    'content': "Twitter co-founder Jack Dorsey's digital payments platform Square has agreed to take over the Australian 'buy now, pay later' firm Afterpay.\r\nThe $29bn (A$39bn; £21bn) deal is to be Australia's bigge… [+1832 chars]",
#    'description': 'The $29bn deal for Afterpay will create an instalments payment giant in a hugely growing sector.',
#    'publishedAt': '2021-08-02T02:04:04Z',
#    'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'title': "Afterpay: Jack Dorsey's Square in Australia's biggest buyout",
#    'url': 'https://www.bbc.co.uk/news/business-58051815',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/7C19/production/_119696713_gettyimages-1321753195.jpg'},
#   {'author': 'https://www.facebook.com/bbcnews',
#    'content': 'Inside the Bitcoin mine with its own power plant. VideoInside the Bitcoin mine with its own power plant',
#    'description': 'The expected impact of winter on the NHS and cuts to a drug addict support scheme make the front pages.',
#    'publishedAt': '2021-08-01T07:59:17Z',
#    'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'title': "Scotland's papers: NHS pressures and drug treatment cutbacks",
#    'url': 'https://www.bbc.co.uk/news/uk-scotland-58046343',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1CFB/production/_119691470_comppppppp.jpg'},
#   {'author': 'Russell Brandom',
#    'content': 'Photo by Amelia Holowaty Krales / The Verge\r\n\n \n\n\n Libertarians built a Bitcoin economy in a small New Hampshire town — then feds tore it down The sky was still dark when the agents arrived at Levere… [+22745 chars]',
#    'description': 'Prosecutors say Free Talk Live host Ian Freeman was running an illegal Bitcoin transmittal business — but Freeman says they’re overstepping the law.',
#    'publishedAt': '2021-08-02T13:20:08Z',
#    'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'title': 'Libertarians built a crypto mecca in Keene, New Hampshire — then feds tore it down',
#    'url': 'https://www.theverge.com/22599932/bitcoin-raid-keene-new-hampshire-ian-freeman-libertarian-prosecution',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/V_7ePGMDaI2WAQbhhYWnrAqy9ks=/0x238:2040x1306/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22729628/akrales_210614_4628_0601.jpg'},
#   {'author': 'Jay Peters',
#    'content': 'Afterpay offers a buy now, pay later service\r\nSomebody using a Square product on their phone.\r\nImage: Square\r\nSquare plans to acquire Australian company Afterpay, which offers a buy now, pay later se… [+1428 chars]',
#    'description': 'Square plans to acquire Australian company Afterpay, which offers a “buy now, pay later” service, for $29 billion in stock. Square and Afterpay expect the transaction to close in the first quarter of 2022.',
#    'publishedAt': '2021-08-01T22:45:01Z',
#    'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'title': 'Square to buy Afterpay, which offers a ‘buy now, pay later’ service, for $29 billion in stock',
#    'url': 'https://www.theverge.com/2021/8/1/22605025/square-afterpay-acquisition-buy-now-pay-later-service-29-billion-stock',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/kFMtgkRiaZErkC0gMQQWdEF6W8Q=/0x371:3360x2130/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22754999/sq_online_store_phone.jpeg'},
#   {'author': 'Makena Kelly',
#    'content': 'Gensler called on Congress to give the SEC more authority\r\nOn Tuesday, chair of the US Securities and Exchange Commission Gary Gensler called on Congress to expand the agencys authority in regulating… [+1955 chars]',
#    'description': 'US Securities and Exchange Commission Chaiman Gary Gensler called on Congress to expand the agency’s authority in regulating cryptocurrency trading, lending, and platforms.',
#    'publishedAt': '2021-08-03T18:55:27Z',
#    'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'title': 'SEC chair calls for more power to regulate cryptocurrency',
#    'url': 'https://www.theverge.com/2021/8/3/22608096/cryptocurrency-bitcoin-sec-gary-gensler-regulation',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/6tajwzi3JLpYG19WHS5py7SBvDU=/0x301:4000x2395/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22759029/1234425306.jpg'}],
#  'status': 'ok',
#  'totalResults': 5}

# %% [markdown]
# # **Google Trend**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from pytrends.request import TrendReq
pytrend = TrendReq()
# interest Word
pytrend.build_payload(kw_list=['Covid-19'])
# in each country
pytrend.interest_by_region()
df = pytrend.interest_by_region()
df.head()
#df.reset_index().plot(x='geoName', y='Taylor Swift', figsize=(120, 10), kind ='bar')
#plt.plot(df)
#plt.show()



#Daily Search Trends
# Get Google Hot Trends data
df = pytrend.trending_searches(pn='united_states')
df.head()
#Today
df = pytrend.today_searches(pn='US')


# Get Google Top Charts
df = pytrend.top_charts(2019, hl='en-US', tz=300, geo='GLOBAL')
df.head()

# Get Google Keyword Suggestions
keywords = pytrend.suggestions(keyword='Mercedes Benz')
df = pd.DataFrame(keywords)
df.drop(columns= 'mid')   # This column makes no sense



# Related Queries, returns a dictionary of dataframes
pytrend.build_payload(kw_list=['Coronavirus'])
#related_queries = pytrend.related_queries()
#related_queries.values()

# Related Topics, returns a dictionary of dataframes
related_topic = pytrend.related_topics()
related_topic.values()

# %% [markdown]
# ** over time**

# %%
####################   Input From Excel  ##############
#import pandas as pd
#file = 'example.xlsx'
# Load spreadsheet
#xl = pd.ExcelFile(file)
# Print the sheet names
#print(xl.sheet_names)
# Load a sheet into a DataFrame by name: df1
#df1 = xl.parse('Sheet1')

#######################################################

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pytrends.request import TrendReq
pytrends = TrendReq()


#Build Payload
kw_list = ['Covid-19', 'Corona Virus', 'Corona', 'Covid 19', 'epidemic']
#d=pytrends.suggestions('Covid')


pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='US-VA', gprop='')


#Find Cat in https://github.com/pat310/google-trends-api/wiki/Google-Trends-Categories
#Time Specific dates, 'YYYY-MM-DD YYYY-MM-DD' example '2016-12-14 2017-01-25'
#GEO  'GB-ENG', 'US-AL'  'FR, MX, GB'  serach in  https://en.wikipedia.org/wiki/ISO_3166-2
# timeframe='today 3-m','today 3-d','today 3-H','today 3-y'
#gprop='' can be images, news, youtube or froogle 
########################


# interest Word
#pytrends.build_payload(kw_list=['Covid-19'])
df =pytrends.interest_over_time()
#plt.plot(df)
#plt.show()





############# Save To Excel ############################
# Install 
# Specify a writer
writer = pd.ExcelWriter('example.xlsx', engine='xlsxwriter') 
# Write your DataFrame to a file     
df.to_excel(writer, 'Sheet1')
# Save the result 
writer.save()

# %% [markdown]
# # gmt gEOGRPGY

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -bfp /usr/local
# !conda update conda -y -q
# !conda config --prepend channels conda-forge
# !conda install -q -y --prefix /usr/local python=3.8 pygmt

import sys
import os
sys.path.append('/usr/local/lib/python3.8/site-packages')
os.environ["GMT_LIBRARY_PATH"]="/usr/local/lib"
# Out:
# --2021-03-07 06:51:01--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94235922 (90M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  89.87M   250MB/s    in 0.4s
#
# 2021-03-07 06:51:01 (250 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [94235922/94235922]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py38h27cfd23_1003
#     - ca-certificates==2020.10.14=0
#     - certifi==2020.6.20=pyhd3eb1b0_3
#     - cffi==1.14.3=py38h261ae71_2
#     - chardet==3.0.4=py38h06a4308_1003
#     - conda-package-handling==1.7.2=py38h03888b9_0
#     - conda==4.9.2=py38h06a4308_0
#     - cryptography==3.2.1=py38h3c74f83_1
#     - idna==2.10=py_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20191231=h14c3975_1
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1h=h7b6447c_0
#     - pip==20.2.4=py38h06a4308_0
#     - pycosat==0.6.3=py38h7b6447c_1
#     - pycparser==2.20=py_2
#     - pyopenssl==19.1.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py38h06a4308_0
#     - python==3.8.5=h7579374_1
#     - readline==8.0=h7b6447c_0
#     - requests==2.24.0=py_0
#     - ruamel_yaml==0.15.87=py38h7b6447c_1
#     - setuptools==50.3.1=py38h06a4308_1
#     - six==1.15.0=py38h06a4308_0
#     - sqlite==3.33.0=h62c20be_0
#     - tk==8.6.10=hbc83047_0
#     - tqdm==4.51.0=pyhd3eb1b0_0
#     - urllib3==1.25.11=py_0
#     - wheel==0.35.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py38h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.10.14-0
#   certifi            pkgs/main/noarch::certifi-2020.6.20-pyhd3eb1b0_3
#   cffi               pkgs/main/linux-64::cffi-1.14.3-py38h261ae71_2
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py38h06a4308_1003
#   conda              pkgs/main/linux-64::conda-4.9.2-py38h06a4308_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.7.2-py38h03888b9_0
#   cryptography       pkgs/main/linux-64::cryptography-3.2.1-py38h3c74f83_1
#   idna               pkgs/main/noarch::idna-2.10-py_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20191231-h14c3975_1
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_1
#   openssl            pkgs/main/linux-64::openssl-1.1.1h-h7b6447c_0
#   pip                pkgs/main/linux-64::pip-20.2.4-py38h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py38h7b6447c_1
#   pycparser          pkgs/main/noarch::pycparser-2.20-py_2
#   pyopenssl          pkgs/main/noarch::pyopenssl-19.1.0-pyhd3eb1b0_1
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py38h06a4308_0
#   python             pkgs/main/linux-64::python-3.8.5-h7579374_1
#   readline           pkgs/main/linux-64::readline-8.0-h7b6447c_0
#   requests           pkgs/main/noarch::requests-2.24.0-py_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py38h7b6447c_1
#   setuptools         pkgs/main/linux-64::setuptools-50.3.1-py38h06a4308_1
#   six                pkgs/main/linux-64::six-1.15.0-py38h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.33.0-h62c20be_0
#   tk                 pkgs/main/linux-64::tk-8.6.10-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.51.0-pyhd3eb1b0_0
#   urllib3            pkgs/main/noarch::urllib3-1.25.11-py_0
#   wheel              pkgs/main/noarch::wheel-0.35.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.1.19  |       h06a4308_0         121 KB
#     certifi-2020.12.5          |   py38h06a4308_0         141 KB
#     cffi-1.14.5                |   py38h261ae71_0         224 KB
#     chardet-4.0.0              |py38h06a4308_1003         194 KB
#     cryptography-3.3.1         |   py38h3c74f83_1         567 KB
#     idna-2.10                  |     pyhd3eb1b0_0          52 KB
#     openssl-1.1.1j             |       h27cfd23_0         2.5 MB
#     pip-21.0.1                 |   py38h06a4308_0         1.8 MB
#     pyopenssl-20.0.1           |     pyhd3eb1b0_1          49 KB
#     readline-8.1               |       h27cfd23_0         362 KB
#     requests-2.25.1            |     pyhd3eb1b0_0          52 KB
#     setuptools-52.0.0          |   py38h06a4308_0         714 KB
#     tqdm-4.56.0                |     pyhd3eb1b0_0          80 KB
#     urllib3-1.26.3             |     pyhd3eb1b0_0         105 KB
#     wheel-0.36.2               |     pyhd3eb1b0_0          33 KB
#     ------------------------------------------------------------
#                                            Total:         6.9 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                              2020.10.14-0 --> 2021.1.19-h06a4308_0
#   certifi            pkgs/main/noarch::certifi-2020.6.20-p~ --> pkgs/main/linux-64::certifi-2020.12.5-py38h06a4308_0
#   cffi                                1.14.3-py38h261ae71_2 --> 1.14.5-py38h261ae71_0
#   chardet                           3.0.4-py38h06a4308_1003 --> 4.0.0-py38h06a4308_1003
#   cryptography                         3.2.1-py38h3c74f83_1 --> 3.3.1-py38h3c74f83_1
#   openssl                                 1.1.1h-h7b6447c_0 --> 1.1.1j-h27cfd23_0
#   pip                                 20.2.4-py38h06a4308_0 --> 21.0.1-py38h06a4308_0
#   pyopenssl                             19.1.0-pyhd3eb1b0_1 --> 20.0.1-pyhd3eb1b0_1
#   readline                                   8.0-h7b6447c_0 --> 8.1-h27cfd23_0
#   requests                                      2.24.0-py_0 --> 2.25.1-pyhd3eb1b0_0
#   setuptools                          50.3.1-py38h06a4308_1 --> 52.0.0-py38h06a4308_0
#   tqdm                                  4.51.0-pyhd3eb1b0_0 --> 4.56.0-pyhd3eb1b0_0
#   urllib3                                      1.25.11-py_0 --> 1.26.3-pyhd3eb1b0_0
#   wheel                                 0.35.1-pyhd3eb1b0_0 --> 0.36.2-pyhd3eb1b0_0
#
# The following packages will be DOWNGRADED:
#
#   idna                                            2.10-py_0 --> 2.10-pyhd3eb1b0_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pygmt
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     atk-1.0-2.36.0             |       h3371d22_4         560 KB  conda-forge
#     boost-cpp-1.74.0           |       hc6e9bd1_2        16.3 MB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
#     cairo-1.16.0               |    h7979940_1007         1.5 MB  conda-forge
#     certifi-2020.12.5          |   py38h578d9bd_1         143 KB  conda-forge
#     cfitsio-3.470              |       hb418390_7         1.3 MB  conda-forge
#     cftime-1.4.1               |   py38h5c078b8_0         325 KB  conda-forge
#     chrpath-0.16               |    h14c3975_1001          29 KB  conda-forge
#     conda-4.9.2                |   py38h578d9bd_0         3.0 MB  conda-forge
#     curl-7.75.0                |       h979ede3_0         147 KB  conda-forge
#     dbus-1.13.6                |       hfdff14a_1         585 KB  conda-forge
#     dcw-gmt-1.1.4              |             1001        20.2 MB  conda-forge
#     expat-2.2.10               |       h9c3ff4c_0         164 KB  conda-forge
#     ffmpeg-4.3.1               |       hca11adc_2        91.9 MB  conda-forge
#     fftw-3.3.9                 |nompi_h74d3f13_101         6.4 MB  conda-forge
#     fontconfig-2.13.1          |    hba837de_1004         344 KB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     freexl-1.0.5               |    h516909a_1002          46 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     gdal-3.2.1                 |   py38hc0b2d6b_8         1.5 MB  conda-forge
#     gdk-pixbuf-2.42.2          |       h0c95a7a_2         611 KB  conda-forge
#     geos-3.9.1                 |       h9c3ff4c_2         1.1 MB  conda-forge
#     geotiff-1.6.0              |       hcf90da6_5         296 KB  conda-forge
#     gettext-0.19.8.1           |    h0b5b191_1005         3.6 MB  conda-forge
#     ghostscript-9.53.3         |       h58526e2_2        56.7 MB  conda-forge
#     giflib-5.2.1               |       h36c2ea0_2          77 KB  conda-forge
#     glib-2.66.7                |       h9c3ff4c_1         443 KB  conda-forge
#     glib-tools-2.66.7          |       h9c3ff4c_1          85 KB  conda-forge
#     gmp-6.2.1                  |       h58526e2_0         806 KB  conda-forge
#     gmt-6.1.1                  |       hbd5eb69_5        30.5 MB  conda-forge
#     gnuplot-5.4.1              |       hc654d65_1         1.2 MB  conda-forge
#     gnutls-3.6.13              |       h85f3911_1         2.0 MB  conda-forge
#     graphicsmagick-1.3.35      |       h2852e03_2         4.2 MB  conda-forge
#     graphite2-1.3.13           |    h58526e2_1001         102 KB  conda-forge
#     gshhg-gmt-2.3.7            |             1002        54.6 MB  conda-forge
#     gst-plugins-base-1.18.3    |       h04508c2_0         2.5 MB  conda-forge
#     gstreamer-1.18.3           |       h3560a44_0         2.0 MB  conda-forge
#     gtk2-2.24.33               |       hab0c2f8_0         7.3 MB  conda-forge
#     harfbuzz-2.7.4             |       h5cf4720_0         1.9 MB  conda-forge
#     hdf4-4.2.13                |    h10796ff_1004         951 KB  conda-forge
#     hdf5-1.10.6                |nompi_h6a2412b_1114         3.1 MB  conda-forge
#     icu-68.1                   |       h58526e2_0        13.0 MB  conda-forge
#     jpeg-9d                    |       h36c2ea0_0         264 KB  conda-forge
#     json-c-0.15                |       h98cffda_0         274 KB  conda-forge
#     kealib-1.4.14              |       he4dc956_1         186 KB  conda-forge
#     krb5-1.17.2                |       h926e7f8_0         1.4 MB  conda-forge
#     lame-3.100                 |    h7f98852_1001         496 KB  conda-forge
#     libblas-3.9.0              |       8_openblas          11 KB  conda-forge
#     libcblas-3.9.0             |       8_openblas          11 KB  conda-forge
#     libclang-11.1.0            |default_ha53f305_0        19.2 MB  conda-forge
#     libcurl-7.75.0             |       hc4aaa36_0         328 KB  conda-forge
#     libdap4-3.20.6             |       hd7c4107_1        11.4 MB  conda-forge
#     libev-4.33                 |       h516909a_1         104 KB  conda-forge
#     libevent-2.1.10            |       hcdb4288_3         1.1 MB  conda-forge
#     libgcc-ng-9.3.0            |      h2828fa1_18         7.8 MB  conda-forge
#     libgd-2.3.0                |       h47910db_1         297 KB  conda-forge
#     libgdal-3.2.1              |       h6636813_8        13.3 MB  conda-forge
#     libgfortran-ng-9.3.0       |      hff62375_18          22 KB  conda-forge
#     libgfortran5-9.3.0         |      hff62375_18         2.0 MB  conda-forge
#     libglib-2.66.7             |       h3e27bee_1         3.0 MB  conda-forge
#     libgomp-9.3.0              |      h2828fa1_18         376 KB  conda-forge
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     libkml-1.3.0               |    h02e6976_1012         590 KB  conda-forge
#     liblapack-3.9.0            |       8_openblas          11 KB  conda-forge
#     libllvm11-11.1.0           |       hf817b99_0        29.1 MB  conda-forge
#     libnetcdf-4.7.4            |nompi_h56d31a8_107         1.3 MB  conda-forge
#     libnghttp2-1.43.0          |       h812cca2_0         808 KB  conda-forge
#     libopenblas-0.3.12         |pthreads_h4812303_1         8.9 MB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libpq-13.1                 |       hfd2b0eb_2         2.7 MB  conda-forge
#     librttopo-1.1.0            |       h1185371_6         235 KB  conda-forge
#     libspatialite-5.0.1        |       h20cb978_4         4.4 MB  conda-forge
#     libssh2-1.9.0              |       hab1572f_5         225 KB  conda-forge
#     libstdcxx-ng-9.3.0         |      h6de172a_18         4.0 MB  conda-forge
#     libtiff-4.2.0              |       hdc55705_0         633 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libwebp-1.2.0              |       h3452ae3_0          85 KB  conda-forge
#     libwebp-base-1.2.0         |       h7f98852_0         808 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1003         395 KB  conda-forge
#     libxkbcommon-1.0.3         |       he3ba5ed_0         581 KB  conda-forge
#     libxml2-2.9.10             |       h72842e0_3         1.3 MB  conda-forge
#     lz4-c-1.9.3                |       h9c3ff4c_0         179 KB  conda-forge
#     mysql-common-8.0.23        |       ha770c72_1         1.5 MB  conda-forge
#     mysql-libs-8.0.23          |       h935591d_1         1.8 MB  conda-forge
#     netcdf4-1.5.6              |nompi_py38h1cdf482_100         555 KB  conda-forge
#     nettle-3.6                 |       he412f7d_0         6.5 MB  conda-forge
#     nspr-4.29                  |       h9c3ff4c_1         232 KB  conda-forge
#     nss-3.62                   |       hb5efdd6_0         2.1 MB  conda-forge
#     numpy-1.20.1               |   py38h18fd61f_0         5.8 MB  conda-forge
#     openh264-2.1.1             |       h780b84a_0         1.5 MB  conda-forge
#     openjpeg-2.4.0             |       hf7af979_0         525 KB  conda-forge
#     openssl-1.1.1j             |       h7f98852_0         2.1 MB  conda-forge
#     packaging-20.9             |     pyh44b312d_0          35 KB  conda-forge
#     pandas-1.2.3               |   py38h51da96c_0        12.1 MB  conda-forge
#     pango-1.42.4               |       h69149e4_5         533 KB  conda-forge
#     pcre-8.44                  |       he1b5a44_0         261 KB  conda-forge
#     pixman-0.40.0              |       h36c2ea0_0         627 KB  conda-forge
#     poppler-0.89.0             |       h2de54a5_5        15.6 MB  conda-forge
#     poppler-data-0.4.10        |                0         3.8 MB  conda-forge
#     postgresql-13.1            |       h6303168_2         5.2 MB  conda-forge
#     proj-8.0.0                 |       h277dcde_0         3.1 MB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pygmt-0.3.0                |     pyhd8ed1ab_1         6.4 MB  conda-forge
#     pyparsing-2.4.7            |     pyh9f0ad1d_0          60 KB  conda-forge
#     python-3.8.8               |       hdb3f193_4        50.0 MB
#     python-dateutil-2.8.1      |             py_0         220 KB  conda-forge
#     python_abi-3.8             |           1_cp38           4 KB  conda-forge
#     pytz-2021.1                |     pyhd8ed1ab_0         239 KB  conda-forge
#     qt-5.12.9                  |       hda022c4_4        99.5 MB  conda-forge
#     sqlite-3.34.0              |       h74cdb3f_0         1.4 MB  conda-forge
#     tiledb-2.2.4               |       hb9a9e87_1         2.6 MB  conda-forge
#     tzcode-2021a               |       h7f98852_1          68 KB  conda-forge
#     tzdata-2021a               |       he74cb21_0         121 KB  conda-forge
#     x264-1!161.3030            |       h7f98852_0         2.4 MB  conda-forge
#     xarray-0.17.0              |     pyhd8ed1ab_0         561 KB  conda-forge
#     xerces-c-3.2.3             |       h9d8b166_2         1.8 MB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.0.10         |       h7f98852_0          58 KB  conda-forge
#     xorg-libsm-1.2.3           |    hd9c2040_1000          26 KB  conda-forge
#     xorg-libx11-1.7.0          |       h7f98852_0         923 KB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h7f98852_1          54 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h7f98852_1003          32 KB  conda-forge
#     xorg-libxt-1.2.1           |       h7f98852_2         375 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h7f98852_1002          28 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     zstd-1.4.9                 |       ha95c52a_0         431 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       683.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-1_gnu
#   atk-1.0            conda-forge/linux-64::atk-1.0-2.36.0-h3371d22_4
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.74.0-hc6e9bd1_2
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.17.1-h7f98852_1
#   cairo              conda-forge/linux-64::cairo-1.16.0-h7979940_1007
#   cfitsio            conda-forge/linux-64::cfitsio-3.470-hb418390_7
#   cftime             conda-forge/linux-64::cftime-1.4.1-py38h5c078b8_0
#   chrpath            conda-forge/linux-64::chrpath-0.16-h14c3975_1001
#   curl               conda-forge/linux-64::curl-7.75.0-h979ede3_0
#   dbus               conda-forge/linux-64::dbus-1.13.6-hfdff14a_1
#   dcw-gmt            conda-forge/linux-64::dcw-gmt-1.1.4-1001
#   expat              conda-forge/linux-64::expat-2.2.10-h9c3ff4c_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-4.3.1-hca11adc_2
#   fftw               conda-forge/linux-64::fftw-3.3.9-nompi_h74d3f13_101
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-hba837de_1004
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   freexl             conda-forge/linux-64::freexl-1.0.5-h516909a_1002
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gdal               conda-forge/linux-64::gdal-3.2.1-py38hc0b2d6b_8
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.2-h0c95a7a_2
#   geos               conda-forge/linux-64::geos-3.9.1-h9c3ff4c_2
#   geotiff            conda-forge/linux-64::geotiff-1.6.0-hcf90da6_5
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   ghostscript        conda-forge/linux-64::ghostscript-9.53.3-h58526e2_2
#   giflib             conda-forge/linux-64::giflib-5.2.1-h36c2ea0_2
#   glib               conda-forge/linux-64::glib-2.66.7-h9c3ff4c_1
#   glib-tools         conda-forge/linux-64::glib-tools-2.66.7-h9c3ff4c_1
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gmt                conda-forge/linux-64::gmt-6.1.1-hbd5eb69_5
#   gnuplot            conda-forge/linux-64::gnuplot-5.4.1-hc654d65_1
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   graphicsmagick     conda-forge/linux-64::graphicsmagick-1.3.35-h2852e03_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h58526e2_1001
#   gshhg-gmt          conda-forge/linux-64::gshhg-gmt-2.3.7-1002
#   gst-plugins-base   conda-forge/linux-64::gst-plugins-base-1.18.3-h04508c2_0
#   gstreamer          conda-forge/linux-64::gstreamer-1.18.3-h3560a44_0
#   gtk2               conda-forge/linux-64::gtk2-2.24.33-hab0c2f8_0
#   harfbuzz           conda-forge/linux-64::harfbuzz-2.7.4-h5cf4720_0
#   hdf4               conda-forge/linux-64::hdf4-4.2.13-h10796ff_1004
#   hdf5               conda-forge/linux-64::hdf5-1.10.6-nompi_h6a2412b_1114
#   icu                conda-forge/linux-64::icu-68.1-h58526e2_0
#   jpeg               conda-forge/linux-64::jpeg-9d-h36c2ea0_0
#   json-c             conda-forge/linux-64::json-c-0.15-h98cffda_0
#   kealib             conda-forge/linux-64::kealib-1.4.14-he4dc956_1
#   krb5               conda-forge/linux-64::krb5-1.17.2-h926e7f8_0
#   lame               conda-forge/linux-64::lame-3.100-h7f98852_1001
#   libblas            conda-forge/linux-64::libblas-3.9.0-8_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-8_openblas
#   libclang           conda-forge/linux-64::libclang-11.1.0-default_ha53f305_0
#   libcurl            conda-forge/linux-64::libcurl-7.75.0-hc4aaa36_0
#   libdap4            conda-forge/linux-64::libdap4-3.20.6-hd7c4107_1
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libevent           conda-forge/linux-64::libevent-2.1.10-hcdb4288_3
#   libgd              conda-forge/linux-64::libgd-2.3.0-h47910db_1
#   libgdal            conda-forge/linux-64::libgdal-3.2.1-h6636813_8
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-9.3.0-hff62375_18
#   libgfortran5       conda-forge/linux-64::libgfortran5-9.3.0-hff62375_18
#   libglib            conda-forge/linux-64::libglib-2.66.7-h3e27bee_1
#   libgomp            conda-forge/linux-64::libgomp-9.3.0-h2828fa1_18
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   libkml             conda-forge/linux-64::libkml-1.3.0-h02e6976_1012
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-8_openblas
#   libllvm11          conda-forge/linux-64::libllvm11-11.1.0-hf817b99_0
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.7.4-nompi_h56d31a8_107
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.12-pthreads_h4812303_1
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libpq              conda-forge/linux-64::libpq-13.1-hfd2b0eb_2
#   librttopo          conda-forge/linux-64::librttopo-1.1.0-h1185371_6
#   libspatialite      conda-forge/linux-64::libspatialite-5.0.1-h20cb978_4
#   libssh2            conda-forge/linux-64::libssh2-1.9.0-hab1572f_5
#   libtiff            conda-forge/linux-64::libtiff-4.2.0-hdc55705_0
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libwebp            conda-forge/linux-64::libwebp-1.2.0-h3452ae3_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.0-h7f98852_0
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1003
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.0.3-he3ba5ed_0
#   libxml2            conda-forge/linux-64::libxml2-2.9.10-h72842e0_3
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_0
#   mysql-common       conda-forge/linux-64::mysql-common-8.0.23-ha770c72_1
#   mysql-libs         conda-forge/linux-64::mysql-libs-8.0.23-h935591d_1
#   netcdf4            conda-forge/linux-64::netcdf4-1.5.6-nompi_py38h1cdf482_100
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   nspr               conda-forge/linux-64::nspr-4.29-h9c3ff4c_1
#   nss                conda-forge/linux-64::nss-3.62-hb5efdd6_0
#   numpy              conda-forge/linux-64::numpy-1.20.1-py38h18fd61f_0
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hf7af979_0
#   packaging          conda-forge/noarch::packaging-20.9-pyh44b312d_0
#   pandas             conda-forge/linux-64::pandas-1.2.3-py38h51da96c_0
#   pango              conda-forge/linux-64::pango-1.42.4-h69149e4_5
#   pcre               conda-forge/linux-64::pcre-8.44-he1b5a44_0
#   pixman             conda-forge/linux-64::pixman-0.40.0-h36c2ea0_0
#   poppler            conda-forge/linux-64::poppler-0.89.0-h2de54a5_5
#   poppler-data       conda-forge/noarch::poppler-data-0.4.10-0
#   postgresql         conda-forge/linux-64::postgresql-13.1-h6303168_2
#   proj               conda-forge/linux-64::proj-8.0.0-h277dcde_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pygmt              conda-forge/noarch::pygmt-0.3.0-pyhd8ed1ab_1
#   pyparsing          conda-forge/noarch::pyparsing-2.4.7-pyh9f0ad1d_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.1-py_0
#   python_abi         conda-forge/linux-64::python_abi-3.8-1_cp38
#   pytz               conda-forge/noarch::pytz-2021.1-pyhd8ed1ab_0
#   qt                 conda-forge/linux-64::qt-5.12.9-hda022c4_4
#   tiledb             conda-forge/linux-64::tiledb-2.2.4-hb9a9e87_1
#   tzcode             conda-forge/linux-64::tzcode-2021a-h7f98852_1
#   tzdata             conda-forge/noarch::tzdata-2021a-he74cb21_0
#   x264               conda-forge/linux-64::x264-1!161.3030-h7f98852_0
#   xarray             conda-forge/noarch::xarray-0.17.0-pyhd8ed1ab_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.3-h9d8b166_2
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h7f98852_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-hd9c2040_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.0-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-libxt         conda-forge/linux-64::xorg-libxt-1.2.1-h7f98852_2
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   zstd               conda-forge/linux-64::zstd-1.4.9-ha95c52a_0
#
# The following packages will be UPDATED:
#
#   certifi            pkgs/main::certifi-2020.12.5-py38h06a~ --> conda-forge::certifi-2020.12.5-py38h578d9bd_1
#   libgcc-ng           pkgs/main::libgcc-ng-9.1.0-hdf63c60_0 --> conda-forge::libgcc-ng-9.3.0-h2828fa1_18
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.1.0-hdf63c6~ --> conda-forge::libstdcxx-ng-9.3.0-h6de172a_18
#   python                                   3.8.5-h7579374_1 --> 3.8.8-hdb3f193_4
#   sqlite                pkgs/main::sqlite-3.33.0-h62c20be_0 --> conda-forge::sqlite-3.34.0-h74cdb3f_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#   ca-certificates    pkgs/main::ca-certificates-2021.1.19-~ --> conda-forge::ca-certificates-2020.12.5-ha878542_0
#   conda               pkgs/main::conda-4.9.2-py38h06a4308_0 --> conda-forge::conda-4.9.2-py38h578d9bd_0
#   openssl              pkgs/main::openssl-1.1.1j-h27cfd23_0 --> conda-forge::openssl-1.1.1j-h7f98852_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
# done

# %%
! conda create --name gmt6
! conda activate gmt6
# Out:
# WARNING: A conda environment already exists at '/usr/local/envs/gmt6'
# Remove existing environment (y/[n])? y
#
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/gmt6
#
#
#
# Proceed ([y]/n)? y
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate gmt6
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
! conda config --prepend channels conda-forge
! conda install python=3.9 pygmt pip numpy pandas xarray netcdf4 packaging gmt pytest pytest-mpl
# Out:
# Warning: 'conda-forge' already in 'channels' list, moving to the top
# done
# done
#
# # All requested packages already installed.

# %%
! conda activate gmt6
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !conda create --name pygmt --channel conda-forge pygmt
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/pygmt
#
#   added / updated specs:
#     - pygmt
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ld_impl_linux-64-2.35.1    |       hea4e1c9_2         618 KB  conda-forge
#     libedit-3.1.20191231       |       he28a2e2_2         121 KB  conda-forge
#     libffi-3.3                 |       h58526e2_2          51 KB  conda-forge
#     ncurses-6.2                |       h58526e2_4         985 KB  conda-forge
#     readline-8.0               |       he28a2e2_2         281 KB  conda-forge
#     tk-8.6.10                  |       h21135ba_1         3.2 MB  conda-forge
#     wheel-0.36.2               |     pyhd3deb0d_0          31 KB  conda-forge
#     xz-5.2.5                   |       h516909a_1         343 KB  conda-forge
#     zlib-1.2.11                |    h516909a_1010         106 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-1_gnu
#   atk-1.0            conda-forge/linux-64::atk-1.0-2.36.0-h3371d22_4
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.74.0-hc6e9bd1_2
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.17.1-h7f98852_1
#   ca-certificates    conda-forge/linux-64::ca-certificates-2020.12.5-ha878542_0
#   cairo              conda-forge/linux-64::cairo-1.16.0-h7979940_1007
#   certifi            conda-forge/linux-64::certifi-2020.12.5-py39hf3d152e_1
#   cfitsio            conda-forge/linux-64::cfitsio-3.470-hb418390_7
#   cftime             conda-forge/linux-64::cftime-1.4.1-py39hce5d2b2_0
#   chrpath            conda-forge/linux-64::chrpath-0.16-h14c3975_1001
#   curl               conda-forge/linux-64::curl-7.75.0-h979ede3_0
#   dbus               conda-forge/linux-64::dbus-1.13.6-hfdff14a_1
#   dcw-gmt            conda-forge/linux-64::dcw-gmt-1.1.4-1001
#   expat              conda-forge/linux-64::expat-2.2.10-h9c3ff4c_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-4.3.1-hca11adc_2
#   fftw               conda-forge/linux-64::fftw-3.3.9-nompi_h74d3f13_101
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-hba837de_1004
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   freexl             conda-forge/linux-64::freexl-1.0.5-h516909a_1002
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gdal               conda-forge/linux-64::gdal-3.2.1-py39h409cc32_8
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.2-h0c95a7a_2
#   geos               conda-forge/linux-64::geos-3.9.1-h9c3ff4c_2
#   geotiff            conda-forge/linux-64::geotiff-1.6.0-hcf90da6_5
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   ghostscript        conda-forge/linux-64::ghostscript-9.53.3-h58526e2_2
#   giflib             conda-forge/linux-64::giflib-5.2.1-h36c2ea0_2
#   glib               conda-forge/linux-64::glib-2.66.7-h9c3ff4c_1
#   glib-tools         conda-forge/linux-64::glib-tools-2.66.7-h9c3ff4c_1
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gmt                conda-forge/linux-64::gmt-6.1.1-hbd5eb69_5
#   gnuplot            conda-forge/linux-64::gnuplot-5.4.1-hc654d65_1
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   graphicsmagick     conda-forge/linux-64::graphicsmagick-1.3.35-h2852e03_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h58526e2_1001
#   gshhg-gmt          conda-forge/linux-64::gshhg-gmt-2.3.7-1002
#   gst-plugins-base   conda-forge/linux-64::gst-plugins-base-1.18.3-h04508c2_0
#   gstreamer          conda-forge/linux-64::gstreamer-1.18.3-h3560a44_0
#   gtk2               conda-forge/linux-64::gtk2-2.24.33-hab0c2f8_0
#   harfbuzz           conda-forge/linux-64::harfbuzz-2.7.4-h5cf4720_0
#   hdf4               conda-forge/linux-64::hdf4-4.2.13-h10796ff_1004
#   hdf5               conda-forge/linux-64::hdf5-1.10.6-nompi_h6a2412b_1114
#   icu                conda-forge/linux-64::icu-68.1-h58526e2_0
#   jpeg               conda-forge/linux-64::jpeg-9d-h36c2ea0_0
#   json-c             conda-forge/linux-64::json-c-0.15-h98cffda_0
#   kealib             conda-forge/linux-64::kealib-1.4.14-he4dc956_1
#   krb5               conda-forge/linux-64::krb5-1.17.2-h926e7f8_0
#   lame               conda-forge/linux-64::lame-3.100-h7f98852_1001
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.35.1-hea4e1c9_2
#   libblas            conda-forge/linux-64::libblas-3.9.0-8_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-8_openblas
#   libclang           conda-forge/linux-64::libclang-11.1.0-default_ha53f305_0
#   libcurl            conda-forge/linux-64::libcurl-7.75.0-hc4aaa36_0
#   libdap4            conda-forge/linux-64::libdap4-3.20.6-hd7c4107_1
#   libedit            conda-forge/linux-64::libedit-3.1.20191231-he28a2e2_2
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libevent           conda-forge/linux-64::libevent-2.1.10-hcdb4288_3
#   libffi             conda-forge/linux-64::libffi-3.3-h58526e2_2
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-9.3.0-h2828fa1_18
#   libgd              conda-forge/linux-64::libgd-2.3.0-h47910db_1
#   libgdal            conda-forge/linux-64::libgdal-3.2.1-h6636813_8
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-9.3.0-hff62375_18
#   libgfortran5       conda-forge/linux-64::libgfortran5-9.3.0-hff62375_18
#   libglib            conda-forge/linux-64::libglib-2.66.7-h3e27bee_1
#   libgomp            conda-forge/linux-64::libgomp-9.3.0-h2828fa1_18
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   libkml             conda-forge/linux-64::libkml-1.3.0-h02e6976_1012
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-8_openblas
#   libllvm11          conda-forge/linux-64::libllvm11-11.1.0-hf817b99_0
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.7.4-nompi_h56d31a8_107
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.12-pthreads_h4812303_1
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libpq              conda-forge/linux-64::libpq-13.1-hfd2b0eb_2
#   librttopo          conda-forge/linux-64::librttopo-1.1.0-h1185371_6
#   libspatialite      conda-forge/linux-64::libspatialite-5.0.1-h20cb978_4
#   libssh2            conda-forge/linux-64::libssh2-1.9.0-hab1572f_5
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-9.3.0-h6de172a_18
#   libtiff            conda-forge/linux-64::libtiff-4.2.0-hdc55705_0
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libwebp            conda-forge/linux-64::libwebp-1.2.0-h3452ae3_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.0-h7f98852_0
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1003
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.0.3-he3ba5ed_0
#   libxml2            conda-forge/linux-64::libxml2-2.9.10-h72842e0_3
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_0
#   mysql-common       conda-forge/linux-64::mysql-common-8.0.23-ha770c72_1
#   mysql-libs         conda-forge/linux-64::mysql-libs-8.0.23-h935591d_1
#   ncurses            conda-forge/linux-64::ncurses-6.2-h58526e2_4
#   netcdf4            conda-forge/linux-64::netcdf4-1.5.6-nompi_py39h36800e2_100
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   nspr               conda-forge/linux-64::nspr-4.29-h9c3ff4c_1
#   nss                conda-forge/linux-64::nss-3.62-hb5efdd6_0
#   numpy              conda-forge/linux-64::numpy-1.20.1-py39hdbf815f_0
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hf7af979_0
#   openssl            conda-forge/linux-64::openssl-1.1.1j-h7f98852_0
#   packaging          conda-forge/noarch::packaging-20.9-pyh44b312d_0
#   pandas             conda-forge/linux-64::pandas-1.2.3-py39hde0f152_0
#   pango              conda-forge/linux-64::pango-1.42.4-h69149e4_5
#   pcre               conda-forge/linux-64::pcre-8.44-he1b5a44_0
#   pip                conda-forge/noarch::pip-21.0.1-pyhd8ed1ab_0
#   pixman             conda-forge/linux-64::pixman-0.40.0-h36c2ea0_0
#   poppler            conda-forge/linux-64::poppler-0.89.0-h2de54a5_5
#   poppler-data       conda-forge/noarch::poppler-data-0.4.10-0
#   postgresql         conda-forge/linux-64::postgresql-13.1-h6303168_2
#   proj               conda-forge/linux-64::proj-8.0.0-h277dcde_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pygmt              conda-forge/noarch::pygmt-0.3.0-pyhd8ed1ab_1
#   pyparsing          conda-forge/noarch::pyparsing-2.4.7-pyh9f0ad1d_0
#   python             conda-forge/linux-64::python-3.9.2-hffdb5ce_0_cpython
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.1-py_0
#   python_abi         conda-forge/linux-64::python_abi-3.9-1_cp39
#   pytz               conda-forge/noarch::pytz-2021.1-pyhd8ed1ab_0
#   qt                 conda-forge/linux-64::qt-5.12.9-hda022c4_4
#   readline           conda-forge/linux-64::readline-8.0-he28a2e2_2
#   setuptools         conda-forge/linux-64::setuptools-49.6.0-py39hf3d152e_3
#   six                conda-forge/noarch::six-1.15.0-pyh9f0ad1d_0
#   sqlite             conda-forge/linux-64::sqlite-3.34.0-h74cdb3f_0
#   tiledb             conda-forge/linux-64::tiledb-2.2.4-hb9a9e87_1
#   tk                 conda-forge/linux-64::tk-8.6.10-h21135ba_1
#   tzcode             conda-forge/linux-64::tzcode-2021a-h7f98852_1
#   tzdata             conda-forge/noarch::tzdata-2021a-he74cb21_0
#   wheel              conda-forge/noarch::wheel-0.36.2-pyhd3deb0d_0
#   x264               conda-forge/linux-64::x264-1!161.3030-h7f98852_0
#   xarray             conda-forge/noarch::xarray-0.17.0-pyhd8ed1ab_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.3-h9d8b166_2
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h7f98852_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-hd9c2040_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.0-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-libxt         conda-forge/linux-64::xorg-libxt-1.2.1-h7f98852_2
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   xz                 conda-forge/linux-64::xz-5.2.5-h516909a_1
#   zlib               conda-forge/linux-64::zlib-1.2.11-h516909a_1010
#   zstd               conda-forge/linux-64::zstd-1.4.9-ha95c52a_0
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# ld_impl_linux-64-2.3 | 618 KB    | : 100% 1.0/1 [00:00<00:00,  5.08it/s]
# zlib-1.2.11          | 106 KB    | : 100% 1.0/1 [00:00<00:00, 20.47it/s]
# tk-8.6.10            | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.92it/s]
# libedit-3.1.20191231 | 121 KB    | : 100% 1.0/1 [00:00<00:00, 22.90it/s]
# ncurses-6.2          | 985 KB    | : 100% 1.0/1 [00:00<00:00,  3.07it/s]
# libffi-3.3           | 51 KB     | : 100% 1.0/1 [00:00<00:00, 28.22it/s]
# readline-8.0         | 281 KB    | : 100% 1.0/1 [00:00<00:00, 14.36it/s]
# wheel-0.36.2         | 31 KB     | : 100% 1.0/1 [00:00<00:00, 31.04it/s]
# xz-5.2.5             | 343 KB    | : 100% 1.0/1 [00:00<00:00, 11.78it/s]
# \ y
# done
# done
# |
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate pygmt
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda activate pygmt
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
import
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-5974fc3f40b1> in <module>()
# ----> 1 import pygmt
#       2 pygmt.show_versions()
#
# ModuleNotFoundError: No module named 'pygmt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
